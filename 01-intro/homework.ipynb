# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv')

# %%
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# ...

# %%
df.tail()
# Out:
#                                                  Laptop       Status  Brand  \
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished  Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished  Razer
#
#       Model                CPU  RAM  Storage Storage type       GPU  Screen  \
# 2155  Blade      Intel Core i7   16     1000          SSD  RTX 3060    17.3
# 2156  Blade      Intel Core i7   16     1000          SSD  RTX 3070    17.3
# 2157  Blade      Intel Core i7   32     1000          SSD  RTX 3080    17.3
# 2158   Book  Intel Evo Core i7   16     1000          SSD       NaN    13.4
# 2159   Book  Intel Evo Core i7   16      256          SSD       NaN    13.4
#
#      Touch  Final Price
# 2155    No      2699.99
# ...

# %%
df.head(10)
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
# 5  MSI Crosshair 17 C12VF-264XES Intel Core i7-12...    New     MSI
# 6  Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8G...    New  Lenovo
# 7  ASUS VivoBook 15 F515JA-EJ2882W Intel Core i7-...    New    Asus
# 8  Medion Akoya E15415 Intel Core i5-10210U/8GB/2...    New  Medion
# 9  HP Victus 16-d1038ns Intel Core i7-12700H/16GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# ...

# %%
df['Brand'].unique()
# Out:
# array(['Asus', 'Alurin', 'MSI', 'HP', 'Lenovo', 'Medion', 'Acer', 'Apple',
#        'Razer', 'Gigabyte', 'Dell', 'LG', 'Samsung', 'PcCom', 'Microsoft',
#        'Primux', 'Prixton', 'Dynabook Toshiba', 'Thomson', 'Denver',
#        'Deep Gaming', 'Vant', 'Innjoo', 'Jetwing', 'Millenium', 'Realme',
#        'Toshiba'], dtype=object)

# %%
df['Brand'].nunique()
# Out:
# 27

# %%
BRNDS = df['Brand'].unique()

# %%
print("No. of brnds:", len(BRNDS))
# Out:
# No. of brnds: 27

# %%
print("Brands:", BRNDS)
# Out:
# Brands: ['Asus' 'Alurin' 'MSI' 'HP' 'Lenovo' 'Medion' 'Acer' 'Apple' 'Razer'
#  'Gigabyte' 'Dell' 'LG' 'Samsung' 'PcCom' 'Microsoft' 'Primux' 'Prixton'
#  'Dynabook Toshiba' 'Thomson' 'Denver' 'Deep Gaming' 'Vant' 'Innjoo'
#  'Jetwing' 'Millenium' 'Realme' 'Toshiba']

# %%
pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv').head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv')['Brand'].nunique()
# Out:
# 27

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df['fuel_type'].nunique()
# Out:
# 2

# %%
df.isnull()
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                   False          False       False           False
# 1                   False          False       False           False
# 2                   False           True       False           False
# 3                   False          False        True           False
# 4                   False          False       False           False
# ...                   ...            ...         ...             ...
# 9699                False          False       False           False
# 9700                False           True       False           False
# 9701                False          False       False           False
# 9702                False          False       False           False
# 9703                False          False       False           False
#
#       acceleration  model_year  origin  fuel_type  drivetrain  num_doors  \
# ...

# %%
df['fuel_efficiency_mpg'].head(50)
# Out:
# 0     13.231729
# 1     13.688217
# 2     14.246341
# 3     16.912736
# 4     12.488369
# 5     17.271818
# 6     13.210412
# 7     12.848884
# 8     16.823554
# 9     12.298355
# 10    13.386605
# 11    20.504447
# 12    16.175820
# 13    18.792742
# 14    11.871091
# 15    16.756081
# 16    17.516176
# 17    17.658685
# 18    14.735962
# 19    15.097137
# 20    18.889083
# 21    16.077730
# 22    17.080405
# 23    13.738381
# 24     7.853194
# 25    15.906422
# 26    15.089880
# 27    13.048993
# 28    13.411266
# 29    17.349011
# 30    16.852518
# 31    14.045645
# 32    11.029371
# 33    15.767586
# 34    15.353788
# 35    14.671772
# 36    15.011325
# 37    11.704658
# 38    11.645724
# 39    17.322852
# 40    18.630009
# 41    16.890274
# 42    16.416021
# 43    15.039797
# 44    17.600328
# 45    20.728617
# 46    15.932777
# 47    10.089818
# 48    17.983505
# 49    11.257268
# Name: fuel_efficiency_mpg, dtype: float64

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df['vehicle_weight'].sum()
# Out:
# np.float64(29124430.759692907)

# %%
median_before = df['horsepower'].median()
most_frequent = df['horsepower'].mode()[0]
df['horspower'] = df['horsepower'].fillna(most_frequent)
median_after = df['horsepower'].median()

# %%
median_before, most_frequent, median_after
# Out:
# (np.float64(149.0), np.float64(152.0), np.float64(149.0))
